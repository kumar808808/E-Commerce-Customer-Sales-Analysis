# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-5b6a4e01-83c9-47ef-b598-820abd5a10de" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b6a4e01-83c9-47ef-b598-820abd5a10de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
orders=pd.read_csv('olist_orders_dataset.csv')
customers=pd.read_csv("olist_customers_dataset.csv")
products=pd.read_csv("olist_products_dataset.csv")
order_items=pd.read_csv("olist_order_items_dataset.csv")
order_payments=pd.read_csv("olist_order_payments_dataset.csv")

# %%
print("orders shape:",orders.shape),
print("customers",customers.shape),
print("products",products.shape),
print("order_items",order_items.shape),
print("order_payments",order_payments.shape)
# Out:
# orders shape: (99441, 8)
# customers (99441, 5)
# products (32951, 9)
# order_items (112650, 7)
# order_payments (103886, 5)

# %%
print(orders.columns),
print(order_items.columns),
print(order_payments.columns),
print(products.columns),
print(customers.columns)
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')
# Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value'],
#       dtype='object')
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
print(orders.head(5))
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
def audit_framework(df):
  report=pd.DataFrame({
      "columns":df.columns,
      "datatypes":df.dtypes,
      "missing_values":df.isnull().sum(),
      "missing_percentage":(df.isnull().sum()/len(df))*100,
      "unique_vlaues":df.nunique()
  })
  return report.sort_values("missing_percentage",ascending=False)
audit_framework(orders)
# Out:
#                                                      columns datatypes  \
# order_delivered_customer_date  order_delivered_customer_date    object
# order_delivered_carrier_date    order_delivered_carrier_date    object
# order_approved_at                          order_approved_at    object
# order_id                                            order_id    object
# order_purchase_timestamp            order_purchase_timestamp    object
# order_status                                    order_status    object
# customer_id                                      customer_id    object
# order_estimated_delivery_date  order_estimated_delivery_date    object
#
#                                missing_values  missing_percentage  \
# order_delivered_customer_date            2965            2.981668
# order_delivered_carrier_date             1783            1.793023
# order_approved_at                         160            0.160899
# ...

# %%
audit_framework(customers)
# Out:
#                                            columns datatypes  missing_values  \
# customer_id                            customer_id    object               0
# customer_unique_id              customer_unique_id    object               0
# customer_zip_code_prefix  customer_zip_code_prefix     int64               0
# customer_city                        customer_city    object               0
# customer_state                      customer_state    object               0
#
#                           missing_percentage  unique_vlaues
# customer_id                              0.0          99441
# customer_unique_id                       0.0          96096
# customer_zip_code_prefix                 0.0          14994
# customer_city                            0.0           4119
# customer_state                           0.0             27

# %%
audit_framework(products)
# Out:
#                                                columns datatypes  \
# product_category_name            product_category_name    object
# product_description_lenght  product_description_lenght   float64
# product_name_lenght                product_name_lenght   float64
# product_photos_qty                  product_photos_qty   float64
# product_weight_g                      product_weight_g   float64
# product_height_cm                    product_height_cm   float64
# product_length_cm                    product_length_cm   float64
# product_width_cm                      product_width_cm   float64
# product_id                                  product_id    object
#
#                             missing_values  missing_percentage  unique_vlaues
# product_category_name                  610            1.851234             73
# product_description_lenght             610            1.851234           2960
# product_name_lenght                    610            1.851234             66
# ...

# %%
audit_framework(order_items)
# Out:
#                                  columns datatypes  missing_values  \
# order_id                        order_id    object               0
# order_item_id              order_item_id     int64               0
# product_id                    product_id    object               0
# seller_id                      seller_id    object               0
# shipping_limit_date  shipping_limit_date    object               0
# price                              price   float64               0
# freight_value              freight_value   float64               0
#
#                      missing_percentage  unique_vlaues
# order_id                            0.0          98666
# order_item_id                       0.0             21
# product_id                          0.0          32951
# seller_id                           0.0           3095
# shipping_limit_date                 0.0          93318
# price                               0.0           5968
# ...

# %%
audit_framework(order_payments)
# Out:
#                                    columns datatypes  missing_values  \
# order_id                          order_id    object               0
# payment_sequential      payment_sequential     int64               0
# payment_type                  payment_type    object               0
# payment_installments  payment_installments     int64               0
# payment_value                payment_value   float64               0
#
#                       missing_percentage  unique_vlaues
# order_id                             0.0          99440
# payment_sequential                   0.0             29
# payment_type                         0.0              5
# payment_installments                 0.0             24
# payment_value                        0.0          29077

# %%
orders["order_id"].nunique(),len(orders)
# Out:
# (99441, 99441)

# %%
order_items["order_id"].nunique(),len(order_items)
# Out:
# (98666, 112650)

# %%
order_items["price"].describe()
# Out:
# count    112650.000000
# mean        120.653739
# std         183.633928
# min           0.850000
# 25%          39.900000
# 50%          74.990000
# 75%         134.900000
# max        6735.000000
# Name: price, dtype: float64

# %%
(order_items["price"] <= 0).sum()
# Out:
# np.int64(0)

# %%
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payments["payment_value"].isna().sum()
# Out:
# np.int64(0)

# %%
(order_payments["payment_value"]<0).sum()
# Out:
# np.int64(0)

# %%
order_payments["order_id"].isna().sum()
# Out:
# np.int64(0)

# %%
orders_clean=orders[["order_id","customer_id","order_purchase_timestamp"]]

# %%
customers_clean = customers[
    ["customer_id", "customer_state"]
]

order_items_clean = order_items[
    ["order_id", "product_id", "price"]
]

products_clean = products[
    ["product_id", "product_category_name"]
]

payments_clean = order_payments[
    ["order_id", "payment_value"]
]

# %%
orders_clean.isnull().sum()
customers_clean.isnull().sum()
order_items_clean.isnull().sum()
products_clean.isnull().sum()
payments_clean.isnull().sum()
# Out:
# order_id         0
# payment_value    0
# dtype: int64

# %%
import duckdb

# %%
con = duckdb.connect("ecommerce.db")

# %%
con.register("orders",orders_clean),
con.register("customers",customers_clean),
con.register("order_items",order_items_clean),
con.register("products",products_clean),
con.register("payments",payments_clean)

# %%
con.execute("select count(*) from orders_clean").fetchall()
# Out:
# [(99441,)]

# %%
con.execute("select count(*) from payments_clean").fetchall()
# Out:
# [(103886,)]

# %% [markdown]
# total revnue

# %%
con.execute("select sum(payment_value) from  payments").fetchall()
# Out:
# [(16008872.119998775,)]

# %% [markdown]
# total orders

# %%
con.execute("select count(distinct order_id)  from orders_clean").fetchall()
# Out:
# [(99441,)]

# %% [markdown]
# Which product categories generate the most revenue?

# %%
con.execute("SELECT p.product_category_name,SUM(oi.price) AS total_revenue FROM order_items oi JOIN products p ON oi.product_id = p.product_id GROUP BY p.product_category_name ORDER BY total_revenue DESC limit 5").fetchall()
# Out:
# [('beleza_saude', 1258681.339999999),
#  ('relogios_presentes', 1205005.6800000104),
#  ('cama_mesa_banho', 1036988.6800000605),
#  ('esporte_lazer', 988048.9700000347),
#  ('informatica_acessorios', 911954.3200000328)]

# %% [markdown]
# Which states generate the most orders?

# %%
con.execute("SELECT customers.customer_state,COUNT(order_id) as order_count FROM orders INNER JOIN customers ON orders.customer_id=customers.customer_id GROUP BY customers.customer_state ORDER BY  order_count desc limit 10 ").fetchall()
# Out:
# [('SP', 41746),
#  ('RJ', 12852),
#  ('MG', 11635),
#  ('RS', 5466),
#  ('PR', 5045),
#  ('SC', 3637),
#  ('BA', 3380),
#  ('DF', 2140),
#  ('ES', 2033),
#  ('GO', 2020)]

# %% [markdown]
# average value

# %%
con.execute("SELECT SUM(payment_value) / COUNT(DISTINCT order_id) AS avg_order_value FROM payments").fetchall()
# Out:
# [(160.9902666934712,)]

# %% [markdown]
# monthly sales trend

# %%
con.execute("SELECT DATE_TRUNC('month',CAST(order_purchase_timestamp AS TIMESTAMP)) AS month, COUNT(order_id) AS total_orders FROM orders GROUP BY month ORDER BY month;").fetchall()
# Out:
# [(datetime.date(2016, 9, 1), 4),
#  (datetime.date(2016, 10, 1), 324),
#  (datetime.date(2016, 12, 1), 1),
#  (datetime.date(2017, 1, 1), 800),
#  (datetime.date(2017, 2, 1), 1780),
#  (datetime.date(2017, 3, 1), 2682),
#  (datetime.date(2017, 4, 1), 2404),
#  (datetime.date(2017, 5, 1), 3700),
#  (datetime.date(2017, 6, 1), 3245),
#  (datetime.date(2017, 7, 1), 4026),
#  (datetime.date(2017, 8, 1), 4331),
#  (datetime.date(2017, 9, 1), 4285),
#  (datetime.date(2017, 10, 1), 4631),
#  (datetime.date(2017, 11, 1), 7544),
#  (datetime.date(2017, 12, 1), 5673),
#  (datetime.date(2018, 1, 1), 7269),
#  (datetime.date(2018, 2, 1), 6728),
#  (datetime.date(2018, 3, 1), 7211),
#  (datetime.date(2018, 4, 1), 6939),
#  (datetime.date(2018, 5, 1), 6873),
#  (datetime.date(2018, 6, 1), 6167),
#  (datetime.date(2018, 7, 1), 6292),
#  (datetime.date(2018, 8, 1), 6512),
#  (datetime.date(2018, 9, 1), 16),
#  (datetime.date(2018, 10, 1), 4)]

# %%
final_df=con.execute("SELECT o.order_id,CAST(o.order_purchase_timestamp AS TIMESTAMP) AS purchase_date,c.customer_state,p.product_category_name,oi.price,pay.payment_value FROM orders o JOIN customers c ON o.customer_id = c.customer_id JOIN order_items oi ON o.order_id = oi.order_id JOIN products p ON oi.product_id = p.product_id JOIN payments pay ON o.order_id = pay.order_id;").df()

# %%
final_df.to_csv("e-commerce_analysis_dataset.csv",index=False)
